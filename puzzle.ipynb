// %% [markdown]
// <center> <b>Console Puzzle</b> using C# kernel for jupyter notebook <br> </center>
// <center> Install <a href="https://docs.servicestack.net/jupyter-notebooks-csharp#generate-c-jupyter-notebooks>">here</a>. </center>
// <hr width=500>

// %%
using System;
using System.Linq;

// %%
public struct Option<T>
{
    public static Option<T> None => default;
    public static Option<T> Some(T value) => new Option<T>(value);

    readonly bool isSome;
    readonly T value;

    Option(T value)
    {
        this.value = value;
        isSome = this.value is { };
    }

    public bool IsSome(out T value)
    {
        value = this.value;
        return isSome;
    }
}

public enum TypeArete {trou,rien,bosse}

public enum Rotation {nord, est, sud, ouest}

public struct ContoursPiece 
{
    public ContoursPiece(TypeArete haut, TypeArete gauche, TypeArete droite, TypeArete bas)
    {
        Haut = haut;
        Gauche = gauche;
        Droite = droite;
        Bas = bas;
    }

    public TypeArete Haut { get; }
    public TypeArete Gauche { get;}
    public TypeArete Droite { get; }
    public TypeArete Bas { get; }
}

public struct Position
{
    public Position(int x, int y)
    {
        X = x;
        Y = y;
    }

    public int X { get; }
    public int Y { get; }

    public override string ToString() => $"({X}, {Y})";
}

// %%
public class Piece {
    public Position pos;
    public ContoursPiece contours;
    public int id;
    public Rotation rot;

    public Piece(ContoursPiece cp, Position posi, int identifiant){
        contours = cp;
        pos = posi;
        id = identifiant;
        rot = Rotation.ouest;
    }

    public string id2string(){
        if (this.id < 10){
            return ("000" + this.id);
        } else if (this.id < 100){
            return ("00" + this.id);
        } else if (this.id < 1000){
            return ("0" + this.id);
        } else {
            return (""+this.id);
        }
    }

    string DoSwitchH(int i){
            switch(i) {
                case -1: switch(this.contours.Haut ) {
                            case TypeArete.trou: return "└‒‒‒┘";
                            default : return "     ";
                        }
                case 1: switch(this.contours.Haut ) {
                            case TypeArete.bosse: return "┌‒‒‒┐";
                            default : return "     ";
                        }
                case 0: switch(this.contours.Haut ) {
                            case TypeArete.rien : return "‒‒‒‒‒";
                            case TypeArete.bosse: return "┘   └";
                            case TypeArete.trou: return "┐   ┌";
                            default : return "│   │";
                        }
                default: return "   ";
            }
        }
    string DoSwitchG(int i){
        switch(i) {
            case 0: switch(this.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "    |";
                        case TypeArete.bosse : return "|    ";
                        default : return "   ";
                    }
            case -1 : switch(this.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "  ┌―┘";
                        case TypeArete.bosse : return "└―┐  ";
                        default : return "   ";
                    }
            case 1 : switch(this.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "  └―┐";
                        case TypeArete.bosse : return "┌―┘  ";
                        default : return "   ";
                    }
            default : return "jnkfelzdm";
        }
    }
    string DoSwitchD(int i){
        switch(i) {
            case 0: switch(this.contours.Droite ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "│    ";
                        case TypeArete.bosse : return "    │";
                        default : return "   ";
                    }
            case -1: switch(this.contours.Droite ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "└―┐  ";
                        case TypeArete.bosse : return "  ┌―┘";
                        default : return "   ";
                    }
            case 1: switch(this.contours.Droite ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "┌―┘  ";
                        case TypeArete.bosse : return "  └―┐";
                        default : return "   ";
                    }
            default: return "jhkl";
        }
    }
    string DoSwitchB(int i){
        switch(i) {
            case -1: switch(this.contours.Bas ) {
                        case TypeArete.trou : return  "┌‒‒‒┐";
                        default : return "     ";
                    }
        
            case 0: switch(this.contours.Bas ) {
                            case TypeArete.rien : return "‒‒‒‒‒";
                            case TypeArete.trou: return "┘   └";
                            case TypeArete.bosse: return "┐   ┌";
                            default : return "│   │";
                        }
            case 1: switch(this.contours.Bas ) {
                        case TypeArete.bosse: return "└‒‒‒┘";
                        default : return "     ";
                    }
            default: return "   ";
        }
        
    }

    public void ShowSolo(){

        (string,string,string) h = (DoSwitchH(-1),DoSwitchH(0),DoSwitchH(1));
        (string,string,string) g = (DoSwitchG(-1),DoSwitchG(0),DoSwitchG(1));
        (string,string,string) d = (DoSwitchD(-1),DoSwitchD(0),DoSwitchD(1));
        (string,string,string) b = (DoSwitchB(-1),DoSwitchB(0),DoSwitchB(1));

        Console.WriteLine($"      {h.Item3}     ");
        Console.WriteLine($"  ┌―――{h.Item2}―――┐ ");
        Console.WriteLine($"  │   {h.Item1}   │ ");
        Console.WriteLine($"{g.Item3}       {d.Item3}");
        Console.WriteLine($"{g.Item2} {this.id2string()}  {d.Item2}");
        Console.WriteLine($"{g.Item1}       {d.Item1}");
        Console.WriteLine($"  │   {b.Item1}   │ ");
        Console.WriteLine($"  └―――{b.Item2}―――┘ ");
        Console.WriteLine($"      {b.Item3}     "); 
    }

    public String[] ShowInPuzzle(){
        (string,string,string) d = (DoSwitchD(-1),DoSwitchD(0),DoSwitchD(1));
        (string,string,string) b = (DoSwitchB(-1),DoSwitchB(0),DoSwitchB(1));
        String[] layers = new String[7];

        layers[0] = $"           │  ";
        layers[1] = $"         {d.Item3}";
        layers[2] = $"   {this.id2string()}  {d.Item2}";
        layers[3] = $"         {d.Item1}";
        layers[4] = $"   {b.Item1}   │  ";
        layers[5] = $"―――{b.Item2}―――┘――";
        layers[6] = $"   {b.Item3}   │  ";
        return layers;
    }

    public void rotate(Rotation newR){
        if (this.rot == newR){
            return;
        } else {
            int typeRot = (int)this.rot;
            if (typeRot == 3){
                this.rot = (Rotation)0;  
                  
            } else {
                this.rot = (Rotation)((int)(this.rot)+1);
            }
            ContoursPiece ancienContours = this.contours;
            this.contours =  new ContoursPiece (ancienContours.Gauche,ancienContours.Bas,ancienContours.Haut,ancienContours.Droite); //haut, gauche, droite, bas
            rotate(newR);
        }
    }
}

// %%
public class Puzzle {
    private Piece[,] lstP;
    public int height;
    public int width;

    public Puzzle(int w, int h) {
        height = h;
        width = w;
        lstP = new Piece[width,height];
        this.CreatePuzzle();
    }

    private TypeArete GetRandomTypeArete(){
        Random rand = new Random();
        switch (rand.Next(2)){
            case 0: return TypeArete.trou;
            default: return TypeArete.bosse;
        }
    }
    private TypeArete GetMyAreteDependingOn(TypeArete t){
        if (t == TypeArete.trou){
            return TypeArete.bosse;
        } else {
            return TypeArete.trou;
        }
    }
    
    private Piece GeneratePiece(Option<Piece> haut, Option<Piece> gauche, Position pos, int sommeIndex){
        bool pieceG_exists = gauche.IsSome(out Piece pieceG);
        bool pieceH_exists = haut.IsSome(out Piece pieceH); 
        if (!pieceH_exists && !pieceG_exists ){ //cas coins en haut a droite
            return new Piece(new ContoursPiece(TypeArete.rien,TypeArete.rien,GetRandomTypeArete(),GetRandomTypeArete()),pos,sommeIndex);
        } else if (pieceH_exists && !pieceG_exists){ //case coté gauche 
            if (pos.Y == this.height-1){
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),TypeArete.rien,GetRandomTypeArete(),TypeArete.rien),pos,sommeIndex); //cas bas gauche
            } else {
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),TypeArete.rien,GetRandomTypeArete(),GetRandomTypeArete()),pos,sommeIndex); 
            } 
        } else if (!pieceH_exists && pieceG_exists){ // cas coté haut
            if (pos.X == this.width -1){
                return new Piece(new ContoursPiece(TypeArete.rien,GetMyAreteDependingOn(pieceG.contours.Droite),TypeArete.rien,GetRandomTypeArete()),pos,sommeIndex); //cas haut droit
            } else {
                return new Piece(new ContoursPiece(TypeArete.rien,GetMyAreteDependingOn(pieceG.contours.Droite),GetRandomTypeArete(),GetRandomTypeArete()),pos,sommeIndex);
            }
        } else {// quand pieceH_exists && pieceG_exists
            if (pos.X == this.width-1 && pos.Y == this.height -1){ //cas bas droite
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),GetMyAreteDependingOn(pieceG.contours.Droite),TypeArete.rien,TypeArete.rien),pos,sommeIndex);
            } else if (pos.X == this.width-1){ //cas coté droit
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),GetMyAreteDependingOn(pieceG.contours.Droite),TypeArete.rien,GetRandomTypeArete()),pos,sommeIndex);
            } else if (pos.Y == this.height -1){ //cas coté bas
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),GetMyAreteDependingOn(pieceG.contours.Droite),GetRandomTypeArete(),TypeArete.rien),pos,sommeIndex);
            } else { // cas piece lambda
                return new Piece(new ContoursPiece(GetMyAreteDependingOn(pieceH.contours.Bas),GetMyAreteDependingOn(pieceG.contours.Droite),GetRandomTypeArete(),GetRandomTypeArete()),pos,sommeIndex);
            }
        }   
    }

    private void CreatePuzzle(){
        int sommeIndex = 0;
        for (int y = 0; y < this.height;y++){
            for (int x =0; x < this.width;x++){
                Position pos = new Position(x,y);
                Option<Piece> pasDePiece = Option<Piece>.None;
                Piece p= new Piece(new ContoursPiece(TypeArete.rien,TypeArete.rien,TypeArete.rien,TypeArete.rien),new Position(0,0),sommeIndex);
                if (x == 0){
                    if (y == 0){ //cas en haut a gauche
                        p = GeneratePiece(pasDePiece,pasDePiece,pos, sommeIndex);
                    }  else { //cas coté gauche
                        Option<Piece> pieceDuHaut = Option<Piece>.Some(lstP[x,y-1]);
                        p = GeneratePiece(pieceDuHaut,pasDePiece,pos, sommeIndex);
                    }
                } else {
                    if (y == 0){ // cas coté haut
                        Option<Piece> pieceDeGauche = Option<Piece>.Some(lstP[x-1,y]);
                        p = GeneratePiece(pasDePiece,pieceDeGauche,pos, sommeIndex);
                    }  else { //cas reste
                        Option<Piece> pieceDuHaut = Option<Piece>.Some(lstP[x,y-1]);
                        Option<Piece> pieceDeGauche = Option<Piece>.Some(lstP[x-1,y]);
                        p = GeneratePiece(pieceDuHaut,pieceDeGauche,pos, sommeIndex);
                    }
                }
                lstP[x,y] = p;
                sommeIndex++;
            }
        }
        
    }

    public void showPuzzle(){
            for (int y =-1; y < this.height;y++){
                for (int l = 0; l < 7; l++){
                    string line = "";
                    for (int x = 0; x < this.width;x++){
                        if (y == -1){
                            line += "―――‒‒‒‒‒――――――";
                        } else {
                            if (!((y == this.height-1) && (l == 6))){
                                if (line == ""){line = "|";}
                                line += this.lstP[x,y].ShowInPuzzle()[l];
                            }
                            
                        }
                        
                    }
                    
                    Console.WriteLine(line);
                    if (y == -1) {break;}
                    
                }
            }
    }
    public void showPiece(int x , int y){
        this.lstP[x,y].ShowSolo();
    }

    private Piece[] ShuffleArray(Piece[] arrayP, bool rotatePieces)
    {
        System.Random random = new System.Random();
        Piece[] myArrayP = arrayP.OrderBy(x => random.Next()).ToArray();
        Piece[] my2ndArrayP = new Piece[arrayP.Length];

        for(int i =0; i < myArrayP.Length; i++){
             my2ndArrayP[i] = new Piece (myArrayP[i].contours,myArrayP[i].pos, myArrayP[i].id) ;
             if (rotatePieces){my2ndArrayP[i].rotate((Rotation)(random.Next() % 4));}
        }
        return my2ndArrayP;
    }

    public Piece[] toList(bool shuffle){
        Piece[] lst = new Piece[this.width * this.height];
        for (int xi = 0; xi < this.width; xi++){
            for (int yi = 0; yi < this.height; yi++){
                lst[this.height*xi + yi] = this.lstP[xi,yi];
            }
        }
        return shuffle?ShuffleArray(lst,true):lst;
    }
}

// %%
public class Plateau{

    public Puzzle puzzle;
    public (Piece,bool)[] myPieces;
    public Option<Piece>[,] plateau;
    private int width;
    private int height;

    public Plateau(Puzzle p){
        puzzle = p;
        width = p.width;
        height = p.height;
        myPieces = new (Piece,bool)[this.width * this.height];
        plateau = new Option<Piece>[this.width,this.height];
        Piece[] pieces = puzzle.toList(true);
        
        for (int i = 0; i < pieces.Length; i++){
            myPieces[i] = (pieces[i],false);
        }

        for (int x = 0; x < plateau.GetLength(0); x++){
            for (int y = 0; y < plateau.GetLength(1); y++){
                plateau[x,y] = Option<Piece>.None;
            }
        }
    }
    public Option<Piece> givePiece(int id){
        for (int i =0; i < myPieces.Length; i++){
            Piece p = myPieces[i].Item1;
            if (p.id == id){
                return Option<Piece>.Some(p);
            }
        }
        return Option<Piece>.None;
    }
    private bool canIsetHere(Position piecePos,Piece piece){

        bool compatible(TypeArete c1, TypeArete c2){
                return ((c1 == TypeArete.bosse && c2 == TypeArete.trou) || (c1 == TypeArete.trou && c2 == TypeArete.bosse));
        }

        if (piecePos.X == 0 || piecePos.X == this.width-1 || piecePos.Y == 0 || piecePos.Y == this.height){
            if (piecePos.X == 0 && piecePos.Y == 0){ //haut gauche
                
                bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
                bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
                bool compaD;
                bool compaB;

                if (isThereBas){
                compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
                } else { compaB = true;}

                if (isThereDroite){
                compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
                } else { compaD = true;}

                
                return piece.contours.Haut == TypeArete.rien && piece.contours.Gauche == TypeArete.rien && compaB && compaD;

            } else if (piecePos.X == this.width-1 && piecePos.Y == 0){ //haut droit

                bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
                bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
                bool compaB;
                bool compaG;
                
                if (isThereBas){
                compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
                } else { compaB = true;}

                if (isThereGauche){
                compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
                } else { compaG = true;}

                return compaG && compaB && piece.contours.Haut == TypeArete.rien && piece.contours.Droite == TypeArete.rien;

            } else if (piecePos.X == 0 && piecePos.Y == this.height-1){ //bas gauche
                bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
                bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
                bool compaH;
                bool compaD;
                
                if (isThereHaut){
                compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
                } else { compaH = true;}

                if (isThereDroite){
                compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
                } else { compaD = true;}

                return piece.contours.Bas == TypeArete.rien && piece.contours.Gauche == TypeArete.rien &&compaH && compaD;

            } else if (piecePos.X == this.width-1&& piecePos.Y == this.height-1){ //bas droite
                bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
                bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
                bool compaH;
                bool compaG;

                if (isThereHaut){
                compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
                } else { compaH = true;}

                if (isThereGauche){
                compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
                } else { compaG = true;}

                return piece.contours.Bas == TypeArete.rien && piece.contours.Droite == TypeArete.rien && compaG && compaH;
            } else { //cas coté droite gauche haut bas
                if (piecePos.X == 0){ //coté gauche
                    bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
                    bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
                    bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
                    
                    bool compaH;
                    bool compaD;
                    bool compaB;

                    if (isThereHaut){
                    compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
                    } else { compaH = true;}

                    if (isThereBas){
                    compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
                    } else { compaB = true;}

                    if (isThereDroite){
                    compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
                    } else { compaD = true;}

                    return piece.contours.Gauche == TypeArete.rien && compaB && compaD && compaH;
                    
                } else if (piecePos.X == this.width-1){//coté droite
                    bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
                    bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
                    bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
                    
                    bool compaH;
                    bool compaG;
                    bool compaB;

                    if (isThereHaut){
                    compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
                    } else { compaH = true;}

                    if (isThereBas){
                    compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
                    } else { compaB = true;}

                    if (isThereGauche){
                    compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
                    } else { compaG = true;}

                    return piece.contours.Droite == TypeArete.rien && compaH && compaB && compaG;

                } else if (piecePos.Y == 0 ){//coté haut
                    bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
                    bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
                    bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
                    
                    bool compaD;
                    bool compaG;
                    bool compaB;

                    if (isThereDroite){
                    compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
                    } else { compaD = true;}

                    if (isThereBas){
                    compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
                    } else { compaB = true;}

                    if (isThereGauche){
                    compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
                    } else { compaG = true;}

                    return piece.contours.Haut == TypeArete.rien && compaD && compaB && compaG;
                    
                } else {// piecePos.Y == this.Height //coté bas
                    bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
                    bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
                    bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
                    
                    bool compaD;
                    bool compaG;
                    bool compaH;

                    if (isThereDroite){
                    compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
                    } else { compaD = true;}

                    if (isThereHaut){
                    compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
                    } else { compaH = true;}

                    if (isThereGauche){
                    compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
                    } else { compaG = true;}

                    return piece.contours.Bas == TypeArete.rien && compaD && compaH && compaG;
                }
            }

        } else {
            bool isThereHaut = this.plateau[piecePos.X,piecePos.Y-1].IsSome(out Piece pieceH);
            bool isThereGauche = this.plateau[piecePos.X-1,piecePos.Y].IsSome(out Piece pieceG);
            bool isThereDroite = this.plateau[piecePos.X+1,piecePos.Y].IsSome(out Piece pieceD);
            bool isThereBas = this.plateau[piecePos.X,piecePos.Y+1].IsSome(out Piece pieceB);
            
            bool compaH;
            bool compaG;
            bool compaD;
            bool compaB;

            if (isThereHaut){
                compaH = compatible(pieceH.contours.Bas,piece.contours.Haut);
            } else { compaH = true;}

            if (isThereBas){
                compaB = compatible(pieceB.contours.Haut,piece.contours.Bas);
            } else { compaB = true;}

            if (isThereGauche){
                compaG = compatible(pieceG.contours.Droite,piece.contours.Gauche);
            } else { compaG = true;}

            if (isThereDroite){
                compaD = compatible(pieceD.contours.Gauche,piece.contours.Droite);
            } else { compaD = true;}

            return compaH && compaB && compaG && compaD;

        }
    }
    public void setPiece(int id, Position pos, Rotation rot){
        for (int i =0; i < myPieces.Length; i++){

            bool isTherePieceOnPlateau = this.plateau[pos.X, pos.Y].IsSome(out Piece piecePlateau);

            if (myPieces[i].Item1.id == id && !myPieces[i].Item2 && !isTherePieceOnPlateau){
                
                Piece mp = myPieces[i].Item1;
                mp.rotate(rot);
                if (canIsetHere(pos,mp)){
                    myPieces[i] = (mp,false);
                    this.plateau[pos.X, pos.Y] = Option<Piece>.Some(mp);
                } else {
                    Console.WriteLine("impossible de placer la piece ici");
                }
                
            }
        }
    }

    public void RemovePiece(int id, Position pos){
        bool isTherePieceOnPlateau = this.plateau[pos.X, pos.Y].IsSome(out Piece piecePlateau);

        if (isTherePieceOnPlateau){

            for (int i = 0; i < myPieces.Length; i++){

                if (myPieces[i].Item1.id == piecePlateau.id){
                    myPieces[i] = (myPieces[i].Item1, true);
                    this.plateau[pos.X, pos.Y] = Option<Piece>.None;
                }
                
            }

        }
    }

    public void showPlateau(){
        for (int y =-1; y < puzzle.height;y++){
                for (int l = 0; l < 7; l++){
                    string line = "";
                    for (int x = 0; x < puzzle.width;x++){
                        if (y == -1){
                            line += "―――‒‒‒‒‒――――――";
                        } else {
                            bool isTherePieceOnPlateau = this.plateau[x,y].IsSome(out Piece piecePlateau);
                            Option<Piece> pieceDroite = isTherePiece(new Position(x+1,y));
                            Option<Piece> pieceBas = isTherePiece(new Position(x,y+1));
                            if (!((y == puzzle.height-1) && (l == 6))){
                                if (line == ""){line = "|";}
                                if (!isTherePieceOnPlateau){
                                    line += notPieceButNeeded(pieceDroite,pieceBas)[l];
                                } else {
                                    line += piecePlateau.ShowInPuzzle()[l];
                                }
                                
                            }
                            
                        }
                        
                    }
                    
                    Console.WriteLine(line);
                    if (y == -1) {break;}
                    
                }
            }
    }

    string DoSwitchG(int i, Piece p){
        switch(i) {
            case 0: switch(p.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "    │";
                        case TypeArete.bosse : return "│    ";
                        default : return "   ";
                    }
            case 1: switch(p.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "  └―┐";
                        case TypeArete.bosse : return "┌―┘  ";
                        default : return "   ";
                    }
            case -1: switch(p.contours.Gauche ) {
                        case TypeArete.rien : return "  │  ";
                        case TypeArete.trou : return "  ┌―┘";
                        case TypeArete.bosse : return "└―┐  ";
                        default : return "   ";
                    }
            default: return "jhkl";
        }
    }
    string DoSwitchH(int i, Piece p){
        switch(i) {
            case 1: switch(p.contours.Haut ) {
                        case TypeArete.trou : return  "└‒‒‒┘";
                        default : return "     ";
                    }
        
            case 0: switch(p.contours.Haut ) {
                            case TypeArete.rien : return "‒‒‒‒‒";
                            case TypeArete.trou: return "┐   ┌";
                            case TypeArete.bosse: return "┘   └";
                            default : return "│   │";
                        }
            case -1: switch(p.contours.Haut ) {
                        case TypeArete.bosse: return "┌‒‒‒┐";
                        default : return "     ";
                    }
            default: return "   ";
        }
        
    }
    private Option<Piece> isTherePiece(Position pos){
        if (pos.X >= 0 && pos.X < this.width && pos.Y >= 0 && pos.Y < this.height){
            bool isTherePieceOnPlateau = this.plateau[pos.X,pos.Y].IsSome(out Piece piecePlateau);
            if (isTherePieceOnPlateau){
                return Option<Piece>.Some(piecePlateau);
            } else {
                return Option<Piece>.None;
            }
        } else {
            return Option<Piece>.None;
        }
    }
    private String[] notPieceButNeeded(Option<Piece> droite, Option<Piece> bas){
        bool pieceD_exists = droite.IsSome(out Piece pieceD);
        bool pieceB_exists = bas.IsSome(out Piece pieceB);

        
        String[] layers = new String[7];

        if (pieceD_exists && pieceB_exists){
            (string,string,string) g = (DoSwitchG(-1,pieceD),DoSwitchG(0,pieceD),DoSwitchG(1,pieceD));
            (string,string,string) h = (DoSwitchH(-1,pieceB),DoSwitchH(0,pieceB),DoSwitchH(1,pieceB));
            layers[0] = $"           │  ";
            layers[1] = $"         {g.Item3}";
            layers[2] = $"         {g.Item2}";
            layers[3] = $"         {g.Item1}";
            layers[4] = $"   {h.Item1}   │  ";
            layers[5] = $"―――{h.Item2}―――┘――";
            layers[6] = $"   {h.Item3}   │  ";
        

        } else if (!pieceD_exists && pieceB_exists){
            (string,string,string) h = (DoSwitchH(-1,pieceB),DoSwitchH(0,pieceB),DoSwitchH(1,pieceB));
            layers[0] = $"              ";
            layers[1] = $"              ";
            layers[2] = $"              ";
            layers[3] = $"              ";
            layers[4] = $"   {h.Item1}      ";
            layers[5] = $"―――{h.Item2}―――┐  ";
            layers[6] = $"   {h.Item3}   │  ";
    
        } else if (pieceD_exists && !pieceB_exists){
            (string,string,string) g = (DoSwitchG(-1,pieceD),DoSwitchG(0,pieceD),DoSwitchG(1,pieceD));
            layers[0] = $"           │  ";
            layers[1] = $"         {g.Item3}";
            layers[2] = $"         {g.Item2}";
            layers[3] = $"         {g.Item1}";
            layers[4] = $"           │  ";
            layers[5] = $"           └――";
            layers[6] = $"              ";

        } else {
            layers[0] = $"              ";
            layers[1] = $"              ";
            layers[2] = $"              ";
            layers[3] = $"              ";
            layers[4] = $"              ";
            layers[5] = $"              ";
            layers[6] = $"              ";
        }
        return layers;
    }

}

// %%
Puzzle puzzle = new Puzzle(10,4);

Plateau myPlateau = new Plateau(puzzle);

Piece[] p2 = puzzle.toList(true);

/*for (int i = 0; i < 4; i++){
    Console.WriteLine(p2[2].rot);
    p2[2].ShowSolo();
    
    p2[2].rotate((Rotation)(((int)p2[2].rot+1)%4));

}*/
bool pl1 = myPlateau.givePiece(0).IsSome(out Piece pp1);
bool pl2 = myPlateau.givePiece(1).IsSome(out Piece pp2);

pp1.rotate(Rotation.ouest);
pp2.rotate(Rotation.ouest);

pp1.ShowSolo();
pp2.ShowSolo();

pp1.rotate(Rotation.sud);
pp2.rotate(Rotation.sud);

pp1.ShowSolo();
pp2.ShowSolo();
    
//myPlateau.setPiece(0,new Position(0,2), Rotation.sud);
myPlateau.setPiece(0,new Position(0,1), Rotation.ouest);
//myPlateau.setPiece(1,new Position(0,1), Rotation.sud);
myPlateau.setPiece(1,new Position(1,1), Rotation.ouest);
myPlateau.showPlateau();

puzzle.showPuzzle()
// Out:
//
//   ┌―――‒‒‒‒‒―――┐
//   │           │
//   │           └―┐
//   │   0000      │
//   │           ┌―┘
//   │   ┌‒‒‒┐   │
//   └―――┘   └―――┘
//
//
//   ┌―――‒‒‒‒‒―――┐
//   │           │
//   └―┐       ┌―┘
//     | 0001  │
//   ┌―┘       └―┐
//   │   ┌‒‒‒┐   │
//   └―――┘   └―――┘
//
//       ┌‒‒‒┐
//   ┌―――┘   └―――┐
//   │           │
//   │         ┌―┘
//   │   0000  │
//   │         └―┐
//   │           │
//   └―――‒‒‒‒‒―――┘
//
//
//   ┌―――┐   ┌―――┐
//   │   └‒‒‒┘   │
//   │         ┌―┘
//   │   0001  │
//   │         └―┐
//   │   ┌‒‒‒┐   │
//   └―――┘   └―――┘
//
// ―――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒――――――
// |
// |
// |
// |
// |
// |―――‒‒‒‒‒―――┐  ―――‒‒‒‒‒―――┐
// |           │             │
// |           │             │
// |           └―┐         ┌―┘
// |   0000      │   0001  │
// |           ┌―┘         └―┐
// |   ┌‒‒‒┐   │     ┌‒‒‒┐   │
// |―――┘   └―――┘―――――┘   └―――┘――
// |           │             │
// |
// |
// |
// |
// |
// |
// |
// |
// |
// |
// |
// |
// |
//
// ―――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒―――――――――‒‒‒‒‒――――――
// |           │             │             │             │             │             │             │             │             │             │
// |           └―┐         ┌―┘             └―┐           └―┐           └―┐           └―┐         ┌―┘             └―┐           └―┐           │
// |   0000      │   0001  │       0002      │   0003      │   0004      │   0005      │   0006  │       0007      │   0008      │   0009    │
// |           ┌―┘         └―┐             ┌―┘           ┌―┘           ┌―┘           ┌―┘         └―┐             ┌―┘           ┌―┘           │
// |   ┌‒‒‒┐   │     ┌‒‒‒┐   │             │             │             │     ┌‒‒‒┐   │     ┌‒‒‒┐   │             │             │             │
// |―――┘   └―――┘―――――┘   └―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┘   └―――┘―――――┘   └―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘――
// |           │             │     └‒‒‒┘   │     └‒‒‒┘   │     └‒‒‒┘   │             │             │     └‒‒‒┘   │     └‒‒‒┘   │     └‒‒‒┘   │
// |           │             │             │             │             │             │             │             │             │             │
// |           └―┐           └―┐         ┌―┘             └―┐         ┌―┘             └―┐           └―┐           └―┐           └―┐           │
// |   0010      │   0011      │   0012  │       0013      │   0014  │       0015      │   0016      │   0017      │   0018      │   0019    │
// |           ┌―┘           ┌―┘         └―┐             ┌―┘         └―┐             ┌―┘           ┌―┘           ┌―┘           ┌―┘           │
// |           │     ┌‒‒‒┐   │     ┌‒‒‒┐   │             │             │     ┌‒‒‒┐   │     ┌‒‒‒┐   │     ┌‒‒‒┐   │             │     ┌‒‒‒┐   │
// |―――┐   ┌―――┘―――――┘   └―――┘―――――┘   └―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┘   └―――┘―――――┘   └―――┘―――――┘   └―――┘―――――┐   ┌―――┘―――――┘   └―――┘――
// |   └‒‒‒┘   │             │             │     └‒‒‒┘   │     └‒‒‒┘   │             │             │             │     └‒‒‒┘   │             │
// |           │             │             │             │             │             │             │             │             │             │
// |           └―┐           └―┐           └―┐           └―┐         ┌―┘             └―┐           └―┐           └―┐         ┌―┘             │
// |   0020      │   0021      │   0022      │   0023      │   0024  │       0025      │   0026      │   0027      │   0028  │       0029    │
// |           ┌―┘           ┌―┘           ┌―┘           ┌―┘         └―┐             ┌―┘           ┌―┘           ┌―┘         └―┐             │
// |           │     ┌‒‒‒┐   │     ┌‒‒‒┐   │             │             │             │             │             │     ┌‒‒‒┐   │             │
// |―――┐   ┌―――┘―――――┘   └―――┘―――――┘   └―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┐   ┌―――┘―――――┘   └―――┘―――――┐   ┌―――┘――
// |   └‒‒‒┘   │             │             │     └‒‒‒┘   │     └‒‒‒┘   │     └‒‒‒┘   │     └‒‒‒┘   │     └‒‒‒┘   │             │     └‒‒‒┘   │
// |           │             │             │             │             │             │             │             │             │             │
// |         ┌―┘             └―┐           └―┐         ┌―┘           ┌―┘             └―┐         ┌―┘             └―┐         ┌―┘             │
// |   0030  │       0031      │   0032      │   0033  │       0034  │       0035      │   0036  │       0037      │   0038  │       0039    │
// |         └―┐             ┌―┘           ┌―┘         └―┐           └―┐             ┌―┘         └―┐             ┌―┘         └―┐             │
// |           │             │             │             │             │             │             │             │             │             │
// |―――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘―――――‒‒‒‒‒―――┘――
